# %% [markdown]
# # Ejemplos de simulación de algunas distribuciones de probabilidad

# %%
#config PATH
from os import chdir,getcwd
from platform import system
directory = getcwd()
if system()=='Linux':
    directory_list = directory.split('/')
    chdir('/'.join(directory_list[0:len(directory_list)-1])+'/src')
elif system()=='Windows':
    directory_list = directory.split('\\')
    chdir('\\'.join(directory_list[0:len(directory_list)-1])+'\\src')
else:
    raise OSError('system not suported')

# %% [markdown]
# ## Inicialización del paquete, las distribuciones y algunas funciones auxiliares

# %%
from sim_2024 import *
from sim_2024.variates import *
from matplotlib import pyplot
#matplotlib ipympl
set_seed(14501)

# %% [markdown]
# ## Distribución Bernoulli

# %%
B = Bernoulli(p=0.3)
sample_Bernoulli = B.sample(1000)
try:
    fig_Bernoulli = pyplot.figure(sample=sample_Bernoulli,FigureClass=HistogramFigure,bins=[-0.5,0.5,1.5])
    fig_Bernoulli.axes[0].set_xticks([0,1])
    fig_Bernoulli.axes[0].set_ylim(0,1)
    fig_Bernoulli.axes[0].set_xlim(-0.6,1.6)
    fig_Bernoulli.add_function(B.mass_function)
finally:
    fig_Bernoulli
# Out:
# <HistogramFigure size 2000x1200 with 1 Axes>

# %% [markdown]
# ## Distribución Binomial

# %%
Bn = Binomial(p=0.6,n=10)
sample_binomial = Bn.sample(1000)
try:
    fig_binomial = pyplot.figure(sample=sample_binomial,FigureClass=HistogramFigure,bins=[-0.5+k for k in range(12)])
    fig_binomial.axes[0].set_xticks([k for k in range(11)])
    fig_binomial.axes[0].set_ylim(0,1)
    fig_binomial.axes[0].set_xlim(-0.5,10.5)
finally:
    fig_binomial
# Out:
# <HistogramFigure size 2000x1200 with 1 Axes>

# %% [markdown]
# ## Distribución geométrica

# %%
G = Geometric(p=0.2)
sample_geometric = G.sample(1000)
try:
    fig_geometric = HistogramFigure(sample_geometric,bins=[-0.5+k for k in range(11)],label='Muestra simulada de una distribución geométrica con $p=0.2$')
    fig_geometric.axes[0].set_xticks([k for k in range(11)])
    fig_geometric.axes[0].set_ylim(0,1)
    fig_geometric.axes[0].set_xlim(-0.5,10.5)
finally:
    fig_geometric

# %% [markdown]
# ## Distribución binomial negativa

# %%
Nb = NegativeBinomial(p=0.7,s=3)
sample_negativeb= Nb.sample(1000)
try:
    fig_negativeb = HistogramFigure(sample_negativeb,bins=[-0.5+k for k in range(11)],label='Muestra simulada de una distribución binomial negativa $p=0.7$ y $s=3$')
    fig_negativeb.axes[0].set_xticks([k for k in range(11)])
    fig_negativeb.axes[0].set_ylim(0,1)
    fig_negativeb.axes[0].set_xlim(-0.5,10.5)
finally:
    fig_negativeb

# %%
fig_Bernoulli = pyplot.figure(sample=sample_geometric,FigureClass=HistogramFigure,bins=[-0.5,0.5,1.5])
# Out:
# <HistogramFigure size 2000x1200 with 1 Axes>

# %%
fig_Bernoulli = HistogramFigure(sample_Bernoulli,bins=[-0.5,0.5,1.5])

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 fig_Bernoulli.show()
#
# File C:\Python313\Lib\site-packages\matplotlib\figure.py:2735, in Figure.show(self, warn)
#    2701 """
#    2702 If using a GUI backend with pyplot, display the figure window.
#    2703
#    (...)
#    2732
#    2733 """
#    2734 if self.canvas.manager is None:
# -> 2735     raise AttributeError(
#    2736         "Figure.show works only for figures managed by pyplot, "
#    2737         "normally created by pyplot.figure()")
#    2738 try:
#    2739     self.canvas.manager.show()
#
# AttributeError: Figure.show works only for figures managed by pyplot, normally created by pyplot.figure()

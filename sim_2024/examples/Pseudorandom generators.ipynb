# %% [markdown]
# # sim24 package

# %%
from os import chdir,getcwd
full_path = getcwd()
chdir(full_path+'\\sim_2024')
import generators

# %% [markdown]
# ## Ejemplos generadores

# %%
#gen_1 = generators.multiplicative_congruential_generator(mod=2**31,mult=65539,seed=14501)
gen_1.sample(100)
# Out:
# [0.44255565805360675,
#  0.6552731753326952,
#  0.9486381295137107,
#  0.7943701990880072,
#  0.22847802890464664,
#  0.2215363816358149,
#  0.2729160296730697,
#  0.6436687433160841,
#  0.40576819283887744,
#  0.6415904671885073,
#  0.19762906758114696,
#  0.41146020079031587,
#  0.6900995965115726,
#  0.4374557719565928,
#  0.4138382631354034,
#  0.5459276312030852,
#  0.5510214189998806,
#  0.39277983317151666,
#  0.39748622803017497,
#  0.8498988696373999,
#  0.5220171655528247,
#  0.4830131665803492,
#  0.19992450950667262,
#  0.8524285578168929,
#  0.3152507613413036,
#  0.21964754769578576,
#  0.4806284341029823,
#  0.9069426753558218,
#  0.11600014520809054,
#  0.5335167930461466,
#  0.1570994514040649,
#  0.14094557100906968,
#  0.43177836341783404,
#  0.32216004142537713,
#  0.04695497779175639,
#  0.3822894939221442,
#  0.8711421634070575,
#  0.7862475351430476,
#  0.8772057401947677,
#  0.18700662488117814,
#  0.22718808753415942,
#  0.6800689012743533,
# ...

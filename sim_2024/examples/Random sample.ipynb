# %%
#config PATH
from os import chdir,getcwd
directory = getcwd()
directory_list = directory.split('\\')
chdir('\\'.join(directory_list[0:len(directory_list)-1])+'\\src')

# %%
import sim_2024
import sim_2024.utilities
sim_2024.set_seed(14501)
from matplotlib import pyplot
#%matplotlib ipympl

# %%
sample = [2*sim_2024.rand() for _ in range(100)]
f = sim_2024.utilities.density_function(lambda x : 1/2,0,2)

# %%
try:
    fig_1 = sim_2024.utilities.HistogramFigure(sample,f,bins=[0+2*k/10 for k in range(11)])
    fig_1.axes[0].set_xticks([0.0+k*0.2 for k in range(11)])
finally:
    pyplot.figure(num=fig_1.number)
